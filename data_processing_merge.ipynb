# %%
import pandas as pd
import numpy as np
import locale
locale.setlocale(locale.LC_ALL, '')
import warnings
warnings.filterwarnings('ignore')
import matplotlib as mpl
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing 
import re
import scipy as sp

plt.style.use('fivethirtyeight')

# 노트북 안에 그래프 그리기
# %matplotlib inline
# 그래프 격자로 숫자 범위가 눈에 잘 띄도록 ggplot 스타일 사용
plt.style.use('ggplot')
# 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus']=False

# 컬럼을 다 보여주는 함수
from IPython.display import display
pd.options.display.max_columns = None

# 한글 font 설정
import matplotlib.font_manager as fm

font_name = fm.FontProperties(fname = 'c:/Windows/Fonts/malgun.ttf').get_name()
plt.rc('font',family = font_name)
mpl.rcParams['axes.unicode_minus'] = False

# %%
Product = pd.read_csv('Pruduct.csv')
print("Product")
Search1 = pd.read_csv('Search1.csv')
print("Search1")
Search2 = pd.read_csv('Search2.csv')
print("Search2")
Custom = pd.read_csv('Custom.csv')
print("Custom")
Master = pd.read_csv('Master.csv')
print("Master")
Session = pd.read_csv('Session.csv')
print("Session")
# Out:
# Product
# Search1
# Search2
# Custom
# Master
# Session

# %%
print('Product의 shape',Product.shape)
print("-----------------------------")
print('Search1의 shape',Search1.shape)
print("-----------------------------")
print('Search2의 shape',Search2.shape)
print("-----------------------------")
print('Custom의 shape',Custom.shape)
print("-----------------------------")
print('Master의 shape',Master.shape)
print("-----------------------------")
print('Session의 shape',Session.shape)
# Out:
# Product의 shape (5024906, 8)
# -----------------------------
# Search1의 shape (2884943, 4)
# -----------------------------
# Search2의 shape (8051172, 3)
# -----------------------------
# Custom의 shape (671679, 3)
# -----------------------------
# Master의 shape (847652, 5)
# -----------------------------
# Session의 shape (2712907, 9)

# %% [markdown]
# # 1. 데이터 정제 및 탐색

# %% [markdown]
# ## 1.1 Product

# %%
Product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5024906 entries, 0 to 5024905
# Data columns (total 8 columns):
# CLNT_ID      int64
# SESS_ID      int64
# HITS_SEQ     int64
# PD_C         int64
# PD_ADD_NM    object
# PD_BRA_NM    object
# PD_BUY_AM    object
# PD_BUY_CT    object
# dtypes: int64(4), object(4)
# memory usage: 306.7+ MB

# %%
Product.isnull().sum()
# Out:
# CLNT_ID      0
# SESS_ID      0
# HITS_SEQ     0
# PD_C         0
# PD_ADD_NM    0
# PD_BRA_NM    0
# PD_BUY_AM    0
# PD_BUY_CT    0
# dtype: int64

# %%
# 행동 한번으로 상품을 구매할 수 없다.
Product = Product[Product['HITS_SEQ'] != 1]

# %%
Product.head()
# Out:
#    CLNT_ID   SESS_ID  HITS_SEQ    PD_C                         PD_ADD_NM  \
# 0  4139680   7605037        12  642112                           색상:워터멜론
# 1  4140076  10189797        13  570603  색상:BLK0_(BLK0)BLACK|사이즈:120 / 2개
# 2  4142395   6158159        85  179538                         (not set)
# 3  4144914   7935714        12  554336      색상:블랙|사이즈:160cm(12~13세) / 1개
# 4  4144917   6406509        78  190306                                5개
#
#   PD_BRA_NM PD_BUY_AM PD_BUY_CT
# 0   [바비브라운]    39,000         1
# 1       데상트    39,000         2
# 2     [아베다]    39,000         1
# 3   아디다스 키즈    39,000         1
# 4      데코르테    39,000         5

# %% [markdown]
# - PD_ADD_NM
#     - 정제가 필요할것같은데 좀 더 생각해보자

# %%
# PD_ADD_NM(추가정보) 열에서 | or / 로 세부정보를 구분
# |를 /로 변경하여 /로만 세부정보를 구분하게 하고 /로 세부정보를 분리하여 각각을 리스트로 저장
# 각 리스트 별로 양쪽에 공백자 제거
# 아직 사용 X ngram사용시 단어를 쪼개는데 어려움이 있음

def changeText1(text):
    return text.replace("|",' / ')

def changeText2(text):
    return text.split('/')

def stripText(text):
    a=[]
    for i in range(len(text)):
        a.append(text[i].strip())
    return a

# %%
Product['PD_ADD_NM'] = Product['PD_ADD_NM'].apply(changeText1)
# Product['PD_ADD_NM'] = Product['PD_ADD_NM'].apply(changeText2)
# Product['PD_ADD_NM'] = Product['PD_ADD_NM'].apply(stripText)
Product.head()
# Out:
#    CLNT_ID   SESS_ID  HITS_SEQ    PD_C                           PD_ADD_NM  \
# 0  4139680   7605037        12  642112                             색상:워터멜론
# 1  4140076  10189797        13  570603  색상:BLK0_(BLK0)BLACK / 사이즈:120 / 2개
# 2  4142395   6158159        85  179538                           (not set)
# 3  4144914   7935714        12  554336      색상:블랙 / 사이즈:160cm(12~13세) / 1개
# 4  4144917   6406509        78  190306                                  5개
#
#   PD_BRA_NM PD_BUY_AM PD_BUY_CT
# 0   [바비브라운]    39,000         1
# 1       데상트    39,000         2
# 2     [아베다]    39,000         1
# 3   아디다스 키즈    39,000         1
# 4      데코르테    39,000         5

# %%
Product.nunique()
# Out:
# CLNT_ID       922618
# SESS_ID      2422640
# HITS_SEQ         499
# PD_C          847609
# PD_ADD_NM     759489
# PD_BRA_NM      22716
# PD_BUY_AM      17731
# PD_BUY_CT        361
# dtype: int64

# %%
def cleanText(data):
    text = re.sub('[-=+,#/\?:^$.@*\"★※~&%ㆍ_!』\\‘|\(\)\[\]\<\>`\'…》]', '', data)
    return text

# %%
def cleanblank(data):
    text = re.sub(' ', '', data)
    return text

# %%
# 텍스트에 포함되어 있는 특수문자 제거

Product['PD_ADD_NM'] = Product['PD_ADD_NM'].apply(cleanText)
Product['PD_BRA_NM'] = Product['PD_BRA_NM'].apply(cleanText)
Product['PD_BUY_AM'] = Product['PD_BUY_AM'].apply(cleanText)

# %%
Product['PD_ADD_NM'] = Product['PD_ADD_NM'].apply(cleanblank)

# %%
# PD_BUY_CT 의 1000이상의 값에서 , 발생
# 함수사용이 안됨 아마 , 가 있는데가 있고 없는데가 있어서..? 안되서 str로 강제변환후 , 를 공백으로 대체

Product["PD_BUY_CT"] = Product["PD_BUY_CT"].astype(str)
Product['PD_BUY_CT'] = Product['PD_BUY_CT'].str.replace(',','')
Product["PD_BUY_AM"] = Product["PD_BUY_AM"].astype(str)
Product['PD_BUY_AM'] = Product['PD_BUY_AM'].str.replace(',','')

# int로 형변환
Product['PD_BUY_AM'] = Product['PD_BUY_AM'].astype(int)
Product['PD_BUY_CT'] = Product['PD_BUY_CT'].astype(int)

# %%
Product.head()
# Out:
#    CLNT_ID   SESS_ID  HITS_SEQ    PD_C                PD_ADD_NM PD_BRA_NM  \
# 0  4139680   7605037        12  642112                   색상워터멜론     바비브라운
# 1  4140076  10189797        13  570603  색상BLK0BLK0BLACK사이즈1202개       데상트
# 2  4142395   6158159        85  179538                   notset       아베다
# 3  4144914   7935714        12  554336      색상블랙사이즈160cm1213세1개   아디다스 키즈
# 4  4144917   6406509        78  190306                       5개      데코르테
#
#    PD_BUY_AM  PD_BUY_CT
# 0      39000          1
# 1      39000          2
# 2      39000          1
# 3      39000          1
# 4      39000          5

# %%
# HITS_SEQ의 분포
figure = plt.figure(figsize=(15,8))
sns.distplot(Product['HITS_SEQ'])

# %%
# PD_BUY_AM 의 분포
figure = plt.figure(figsize=(15,8))
sns.kdeplot(Product['PD_BUY_AM'])

# %%
# 가장비싼 물건
Product[Product['PD_BUY_AM']==17779000]
# Out:
#          CLNT_ID  SESS_ID  HITS_SEQ   PD_C PD_ADD_NM   PD_BRA_NM  PD_BUY_AM  \
# 3424550   929827   609951        57  51344        1개  프레드릭콘스탄트시계   17779000
#
#          PD_BUY_CT
# 3424550          1

# %%
# PD_BUY_CT의 분포
figure = plt.figure(figsize=(15,8))
sns.kdeplot(Product['PD_BUY_CT'])

# %%
# 구매금액(건수*가격)의 분포
figure = plt.figure(figsize=(15,8))
sns.kdeplot(Product['PD_BUY_AM']*Product['PD_BUY_CT'])

# %%
BUY_CT = Product[["CLNT_ID","SESS_ID","PD_BUY_CT"]].groupby(['CLNT_ID',"SESS_ID"]).sum().reset_index()
BUY_CT['PD_BUY_CT'].describe()
# Out:
# count    2.708872e+06
# mean     2.182634e+00
# std      6.407434e+00
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      2.000000e+00
# max      2.420000e+03
# Name: PD_BUY_CT, dtype: float64

# %%
# 구매건수의 최대값은 2420건 , 평균 구매 건수 : 2.182634건, 최소 구매건수 1건

# %%
BUY_price = Product[["CLNT_ID","SESS_ID","PD_BUY_AM","PD_BUY_CT"]].groupby(['CLNT_ID',"SESS_ID"]).sum().reset_index()
BUY_price['PD_BUY_price'] = BUY_price['PD_BUY_AM'] * BUY_price['PD_BUY_CT']
BUY_price['PD_BUY_price'].describe()
# Out:
# count    2.708872e+06
# mean     2.782940e+05
# std      3.719853e+06
# min      1.000000e+01
# 25%      3.250000e+04
# 50%      7.500000e+04
# 75%      1.960000e+05
# max      1.542517e+09
# Name: PD_BUY_price, dtype: float64

# %%
# 총구매금액의 최대값 : 1542517000, 평균 총구매금액 : 75000, 총구매금액의 최소값 : 10

# %%
BUY_price['PD_BUY_AM'].min()
# Out:
# 10

# %%
BUY_price['PD_BUY_CT'].min()
# Out:
# 1

# %%
# 상품가격이 100원 이하
Product[Product['PD_BUY_AM']<=100]
# Out:
#        CLNT_ID   SESS_ID  HITS_SEQ    PD_C                   PD_ADD_NM  \
# 263    2543200  10683905         5  402140          상품명랑방모던프린세스EDP60ml
# 264    1716857  10563451        22  504573                      notset
# 265       8752   6876615        19  207981                     색상여스킨1개
# 266      49656   2870637        16   71309              defaultdefault
# 267      59693   5939404        14  208785                    색상남그레이1개
# 268      64014   6132602        90  207981                     색상여스킨1개
# 269      64151    920193       181  783107                          5개
# 270     114575   2825393        76   71306            defaultdefault5개
# 271     138969   6879951        28  207981                     색상여스킨1개
# 272     171668   3652310       169  207981                     색상여스킨1개
# 273     183134    884275        40  783121                          5개
# 274     211530   3984158        50  207981                     색상여스킨1개
# 275     225205   5457967        41  207981                     색상여스킨1개
# 276     225269   5791036       127  207981                     색상여스킨1개
# 277     228960   6788043        17  207981                       색상여스킨
# 278     241426   6143667        99  207981                     색상여스킨1개
# 279     263247   6874489        28  207981                     색상여스킨1개
# 280     288491   5889024        13  207981                     색상여스킨1개
# 281     288491   6378859         9  207981                     색상여스킨1개
# 282     378848   2853956        12   71302            defaultdefault5개
# 283     402512   3066835        20  207981                     색상여스킨1개
# 284     429398   2792997        21   71310              defaultdefault
# 285     535655   6230499        44  643396      원단선택98번손잡이선택구측설치공간천정목재
# 286     554116   3844650        12  207981                       색상여스킨
# 287     575604   3569592        29  179341                맛기능선택장건강치킨1개
# 288     575775   3570867        98  179341                맛기능선택장건강치킨1개
# 289     589444   2654229        17   71302            defaultdefault5개
# 290     748467   4495172        50  552474                 제품선택피치우391개
# 291     754275   2768532        87   71306            defaultdefault5개
# 292     793706   6516907        50  208785                    색상남그레이1개
# ...        ...       ...       ...     ...                         ...
# 51879  4875581   6875455         8  207981                     색상여스킨1개
# 51880  4888403   6057032        13  207981                       색상여스킨
# 51881  4932633   2984962        83  207981                     색상여스킨1개
# 51882  4941920   2602513        33   71308            defaultdefault5개
# 51883  4970712   2808091        89   71310            defaultdefault5개
# 51884  5004934   5646034        67  207981                     색상여스킨1개
# 51885  5009318   6876909        10  207981                     색상여스킨1개
# 51886  5058880   3166538        11  207981                     색상여스킨1개
# 51887  5058880   4112555        11  208785                    색상남그레이1개
# 51888  5058880   5332391        10  207981                     색상여스킨1개
# 51889  5058880   5756250        20  208785                    색상남그레이1개
# 51890  5127773   6826329        81  207981                     색상여스킨1개
# 51891  5155144   3726708        64  643396  원단선택90번손잡이선택구측설치공간벽면목재281개
# 51892  5267682   2911944       136  208785                    색상남그레이1개
# 51893  5294484   2810607        19  208785                    색상남그레이1개
# 51894  5294484   2912512        24  208785                    색상남그레이1개
# 51895  5503095   6429185        22  208785                    색상남그레이1개
# 51896  5503095   6614256        25  208785                    색상남그레이1개
# 51897  5531158   4920744        28  207981                     색상여스킨1개
# 51898  5682537   4335123        14  207981                     색상여스킨1개
# 51899  5682537   4775898        26  207981                     색상여스킨1개
# 51900  5932151    939187        61  783104                          5개
# 51901  6010420   6876383        25  207981                     색상여스킨1개
# 51902  6033923   6904191        18  208785                    색상남그레이1개
# 51903  6040690   4866257        37  207981                     색상여스킨1개
# 51904  6174378   6875959        20  208785                    색상남그레이1개
# 51905  6255016   3513753        13  179341                맛기능선택눈건강오리1개
# 51906  6287872   2705028       198   71308            defaultdefault5개
# 51907  6535670  10895032       141  783121                          5개
# 51908  6557435   6869761         9  207981                     색상여스킨1개
#
#       PD_BRA_NM  PD_BUY_AM  PD_BUY_CT
# 263          랑방         40        115
# 264          코렐         72         24
# 265         올삭스        100          1
# 266         더리얼        100          5
# 267         올삭스        100          1
# 268         올삭스        100          1
# 269        루치펠로        100          5
# 270         더리얼        100          5
# 271         올삭스        100          1
# 272         올삭스        100          1
# 273        루치펠로        100          5
# 274         올삭스        100          1
# 275         올삭스        100          1
# 276         올삭스        100          1
# 277         올삭스        100          1
# 278         올삭스        100          1
# 279         올삭스        100          1
# 280         올삭스        100          1
# 281         올삭스        100          1
# 282         더베터        100          5
# 283         올삭스        100          1
# 284         더리얼        100          5
# 285        리드센스        100        342
# 286         올삭스        100          1
# 287          더독        100          1
# 288          더독        100          1
# 289         더베터        100          5
# 290          24        100        391
# 291         더리얼        100          5
# 292         올삭스        100          1
# ...         ...        ...        ...
# 51879       올삭스        100          1
# 51880       올삭스        100          1
# 51881       올삭스        100          1
# 51882       더리얼        100          5
# 51883       더리얼        100          5
# 51884       올삭스        100          1
# 51885       올삭스        100          1
# 51886       올삭스        100          1
# 51887       올삭스        100          1
# 51888       올삭스        100          1
# 51889       올삭스        100          1
# 51890       올삭스        100          1
# 51891      리드센스        100        281
# 51892       올삭스        100          1
# 51893       올삭스        100          1
# 51894       올삭스        100          1
# 51895       올삭스        100          1
# 51896       올삭스        100          1
# 51897       올삭스        100          1
# 51898       올삭스        100          1
# 51899       올삭스        100          1
# 51900      루치펠로        100          5
# 51901       올삭스        100          1
# 51902       올삭스        100          1
# 51903       올삭스        100          1
# 51904       올삭스        100          1
# 51905        더독        100          1
# 51906       더리얼        100          5
# 51907      루치펠로        100          5
# 51908       올삭스        100          1
#
# [3369 rows x 8 columns]

# %%
# 상품구매건수가 100개이상
Product[Product['PD_BUY_CT']>=100]
# Out:
#          CLNT_ID   SESS_ID  HITS_SEQ    PD_C  \
# 263      2543200  10683905         5  402140
# 285       535655   6230499        44  643396
# 290       748467   4495172        50  552474
# 336      3110203   6258680        31  643396
# 362      4789614   6238505        87  643396
# 379      5432798   4778329        43  644852
# 396      6187459   9488058        57  736543
# 398      5524864   8660052        80  836493
# 399      2149566  10562469        52  736541
# 405      1275411   6590321        97  828515
# 409      2809249   4118274        76  817486
# 420      3489305   9289932        23  817575
# 486      2725012   7386138        15  736373
# 497       279819   1970199         8  687790
# 514       584513   9376658        29  687790
# 950      5919814   2260879        48  643227
# 963       120313   6778158       164  836493
# 964      5078634   2508150        61  836493
# 1033      884524   1793271        27  777659
# 1035     3204455  10731646         8  821032
# 1047     3489305   9300603        27  821085
# 1048     3818375   3155273       167  821085
# 1049     4163815   6509865        96  821085
# 1077     4541863   2103889       104  687790
# 1083     6294909    757285         9  687790
# 1088     6289913   6973045        42  687790
# 1737     1472885   9205414        66  687788
# 1927     5215243   9778173         9  514197
# 1939      748467   4446088        29  552474
# 1965     1894303   7665564         6  643396
# ...          ...       ...       ...     ...
# 1987260  4236802   2861519        12    6975
# 2013521   820884   5051994        74  718518
# 2174952  1676706   3911361         8  840117
# 2218318  1146229   1590443        22  669997
# 2479620   820884   5051994        47    1955
# 2694612  1193347   6202670        80  769281
# 2729948  1193347   6202670        32  769281
# 2870291  3946827   8338963        22  813045
# 2928955   311915   6584560        37  391217
# 2981763  2041668   7319580        77  211134
# 3021197  2041668   7319580        98  211134
# 3060254  2465361   2871523        90  128861
# 3098741  2465361   2871523        90  128861
# 3166600   820884   1963767        48  657768
# 3250832   807356   4948427         5  630476
# 3307627   807356   6099635        26  630476
# 3605336  5413672   3837285        20  662980
# 3645629  5413672   3837285       129  662980
# 3661501  3289736   6822733       195  698823
# 3688081  3289736   6822733       123  698821
# 3881613  1169233   5316024        11  173226
# 4023187  4065293   3482933        72  168942
# 4025465  3140379   3279792        77  168942
# 4028199  4065293   3304988       174  168942
# 4046455  4065293   3304988       240  168942
# 4051349  4065293   3304988       108  168942
# 4074866  4065293   3440476        40  168942
# 4243913  6410735   4701860         9  228634
# 4265103   431508   2684568         9  228634
# 4490351  5431377   1150072         8  228633
#
#                                          PD_ADD_NM  PD_BRA_NM  PD_BUY_AM  \
# 263                             상품명랑방모던프린세스EDP60ml         랑방         40
# 285                         원단선택98번손잡이선택구측설치공간천정목재       리드센스        100
# 290                                    제품선택피치우391개         24        100
# 336                        원단선택83번손잡이선택구측설치공간천정시멘트       리드센스        100
# 362                         원단선택91번손잡이선택구측설치공간천정목재       리드센스        100
# 379                      색상선택14번손잡이선택우측설치공간선택천정시멘트       리드센스        100
# 396                              색상화이트손잡이방향오른쪽417개        창데코        120
# 398                         색상그레이손잡이방향우필수QA사이즈242개        바자르        150
# 399                                  색상브라운손잡이방향오른쪽        창데코        160
# 405                                    손잡이방향좌측172개        코지샵        180
# 409                                       색상그린100개         가쯔        180
# 420          색상WH102화이트손잡이방향좌측필수사항주문메모orQA에사이즈필수기재        바자르        190
# 486                               색상네이비손잡이방향왼쪽307개        창데코        370
# 497                            색상진베이지손잡이방향손잡이우110개         한샘        400
# 514                               색상그레이블루손잡이방향손잡이우         한샘        420
# 950                   원단선택01번손잡이선택우측설치부속선택벽면목재187개       리드센스        100
# 963                          색상피치손잡이방향우필수QA사이즈288개        바자르        150
# 964                         색상그레이손잡이방향좌필수QA사이즈230개        바자르        150
# 1033                              직접입력1우색상아이보리247개        코지샵        320
# 1035     색상800스킨베이지손잡이방향우측필수사항주문메모orQA에사이즈필수기재216개        바자르        320
# 1047           색상OW07화이트손잡이방향우필수사항주문메모orQA에사이즈필수기재        바자르        380
# 1048       색상OW01내추럴손잡이방향우필수사항주문메모orQA에사이즈필수기재400개        바자르        380
# 1049       색상OW07화이트손잡이방향우필수사항주문메모orQA에사이즈필수기재209개        바자르        380
# 1077                          색상그레이블루손잡이방향손잡이좌132개         한샘        400
# 1083                            색상화이트손잡이방향손잡이우168개         한샘        400
# 1088                                 색상그린손잡이방향손잡이우         한샘        420
# 1737                                색상그레이손잡이방향손잡이좌         한샘        920
# 1927                                        notset        닥터지         12
# 1939                                   제품선택피치우391개         24        100
# 1965                        원단선택56번손잡이선택구측설치공간천정목재       리드센스        100
# ...                                            ...        ...        ...
# 1987260                                     notset     티지아이에프      10000
# 2013521                                       290개        정관장      80000
# 2174952                                     notset         영진      11100
# 2218318                                     notset      뉴트로지나      11400
# 2479620                                       390개        정관장     100000
# 2694612                         선택시어버터핸드크림30ml170개        록시땅      14000
# 2729948                         선택시어버터핸드크림30ml170개        록시땅      14000
# 2870291                                       100개       유한양행      14900
# 2928955                                 색상핑크사이즈100        르까프      15000
# 2981763                               색상오렌지사이즈FREE        케이투      15000
# 3021197                               색상오렌지사이즈FREE        케이투      15000
# 3060254                                  색상네이비사이즈S     로썸스튜디오      15070
# 3098741                                  색상네이비사이즈M     로썸스튜디오      15070
# 3166600                           모델명홍삼정플러스240100개        정관장     198000
# 3250832                                     notset      포트메리온     259000
# 3307627                                     notset      포트메리온     259000
# 3605336                                 사이즈100100개        트라이      19500
# 3645629                                 사이즈100100개        트라이      19500
# 3661501                          색상COLORPNKYEL160개         밸롭      19900
# 3688081                          색상COLORGRNBLU160개         밸롭      19900
# 3881613                                옵션비스무스6구화이트         볼빅      23000
# 4023187                                 사이즈000140개  아디다스 오리지널      25000
# 4025465                                 사이즈000200개  아디다스 오리지널      25000
# 4028199                                 사이즈000220개  아디다스 오리지널      25000
# 4046455                                 사이즈000185개  아디다스 오리지널      25000
# 4051349                                 사이즈000185개  아디다스 오리지널      25000
# 4074866                                 사이즈000140개  아디다스 오리지널      25000
# 4243913                            상품명랑방메리미EDP30ML    코익퍼퓸화장품      28890
# 4265103                            상품명랑방메리미EDP30ML    코익퍼퓸화장품      28890
# 4490351                             상품명랑방잔느EDP30ML    코익퍼퓸화장품      30500
#
#          PD_BUY_CT
# 263            115
# 285            342
# 290            391
# 336            242
# 362            547
# 379            336
# 396            417
# 398            242
# 399            118
# 405            172
# 409            100
# 420            224
# 486            307
# 497            110
# 514            136
# 950            187
# 963            288
# 964            230
# 1033           247
# 1035           216
# 1047           242
# 1048           400
# 1049           209
# 1077           132
# 1083           168
# 1088           116
# 1737           504
# 1927           150
# 1939           391
# 1965           153
# ...            ...
# 1987260        100
# 2013521        290
# 2174952        100
# 2218318        188
# 2479620        390
# 2694612        170
# 2729948        170
# 2870291        100
# 2928955        100
# 2981763        100
# 3021197        200
# 3060254        125
# 3098741        109
# 3166600        100
# 3250832        100
# 3307627        120
# 3605336        100
# 3645629        100
# 3661501        160
# 3688081        160
# 3881613        100
# 4023187        140
# 4025465        200
# 4028199        220
# 4046455        185
# 4051349        185
# 4074866        140
# 4243913        108
# 4265103        224
# 4490351        100
#
# [600 rows x 8 columns]

# %% [markdown]
# - PD_BUY_AM이 100 이하인 값들 존재, 이 외에도 더 많을 것으로 추정
# - PD_BUY_CT가 건수가 100개 이상인 값들 존재
# - 이런값들은 아마 이벤트성 제품들일 것으로 보임
# - 이벤트성 제품들의 처리를 어떻게 해야할까?
# - 이벤트성 제품들이 나온 날짜를 확인? / 이벤트성 제품들은 패턴파악이 어려우므로 제거?

# %%
brand = pd.DataFrame(Product['PD_BRA_NM'].value_counts())

# %%
brand[brand['PD_BRA_NM']<=1]
# Out:
#                      PD_BRA_NM
# 124906                       1
# skoot                        1
# 109458                       1
# 디케이코리아                       1
# 104362                       1
# 베게너                          1
# 아바몰리                         1
# 윈드페이스                        1
# 다봉상사                         1
# 다농원                          1
# 황실유기공방                       1
# 108534                       1
# 102338                       1
# 제이제이                         1
# 노이어                          1
# ETWOW                        1
# 애슐리즈                         1
# Matsukawa Hiro Yuki          1
# 에이치에스                        1
# 1861891                      1
# 행담도                          1
# 손앤박화장품                       1
# 여성                           1
# 283573                       1
# Savanna                      1
# HENSCHEL                     1
# 네이쳐플라이                       1
# 비스코티                         1
# 창소다                          1
# 로얄베이비                        1
# ...                        ...
# 엔보우                          1
# 토이예스                         1
# 1841268                      1
# 슬립메이트                        1
# 155737C                      1
# 국산 고급수전                      1
# 세러데이스킨                       1
# 조르쥬레쉬잡화                      1
# 라빠레뜨LAPALETTE                1
# Laser Pegs                   1
# 오프레시                         1
# 1906469                      1
# 스왑플러스                        1
# 19379580904                  1
# 아이스워치시계                      1
# 일구포                          1
# 129622                       1
# 겐지아                          1
# 아꼬야                          1
# 3분할45M                       1
# 조이너스꼼빠니아                     1
# 바츠                           1
# 124898                       1
# 닥터레코멘즈                       1
# 엘라스토리                        1
# NUTZ                         1
# 1863517                      1
# 메세                           1
# 롯데닷컴                         1
# 아이콘팜                         1
#
# [1927 rows x 1 columns]

# %% [markdown]
# - 총 판매 브랜드 중 count가 1인값들이 존재

# %% [markdown]
# ## 1.2 Session

# %%
Session.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2712907 entries, 0 to 2712906
# Data columns (total 9 columns):
# CLNT_ID            int64
# SESS_ID            int64
# SESS_SEQ           int64
# SESS_DT            int64
# TOT_PAG_VIEW_CT    float64
# TOT_SESS_HR_V      object
# DVC_CTG_NM         object
# ZON_NM             object
# CITY_NM            object
# dtypes: float64(1), int64(4), object(4)
# memory usage: 186.3+ MB

# %%
Session.head()
# Out:
#    CLNT_ID   SESS_ID  SESS_SEQ   SESS_DT  TOT_PAG_VIEW_CT TOT_SESS_HR_V  \
# 0  5873599   8641867         9  20180509             82.0         1,890
# 1  5873599   6616320        21  20180611            105.0         1,604
# 2  5873599   5886172        40  20180624             41.0           632
# 3  5873884   1050889        15  20180913            160.0         1,035
# 4  5874461  10298270         5  20180412             13.0           298
#
#   DVC_CTG_NM       ZON_NM  CITY_NM
# 0     mobile      Daejeon  Daejeon
# 1     mobile        Busan    Busan
# 2     mobile      Daejeon  Daejeon
# 3     mobile  Gyeonggi-do   Anyang
# 4     mobile        Seoul    Seoul

# %%
# int형인 SESS_DT를 datetime형태로 형변환
Session['SESS_DT'] = pd.to_datetime(Session['SESS_DT'],format="%Y%m%d")

# year는 2018로 동일하므로 월 / 일 / 요일 변수를 새롭게 만듬
# SESS_DT는 병합에 사용될 수 있는 변수이므로 일단 제거 X
Session['SESS_MONTH'] = Session['SESS_DT'].dt.month
Session['SESS_DAY'] = Session['SESS_DT'].dt.day
Session['SESS_WEEK'] = Session['SESS_DT'].dt.weekday

# %%
# Session['TOT_SESS_HR_V']의 결측치 15000여개의 결측치 삭제
Session = Session[Session['TOT_SESS_HR_V'].notnull()]

# Session TOT_SESS_HR_V 의 형변환 (object -> int64)
Session['TOT_SESS_HR_V'] = Session['TOT_SESS_HR_V'].astype(str)
Session['TOT_SESS_HR_V'] = Session['TOT_SESS_HR_V'].str.replace(',','')
Session['TOT_SESS_HR_V'] = Session['TOT_SESS_HR_V'].astype(int)

# %% [markdown]
# - TOT_PAG_VIEW_CT 의 결측치 처리

# %%
# 예측변수에 사용하기위해 숫자로 매핑시킴
Session['DVC_CTG_NM'] = Session['DVC_CTG_NM'].map({'mobile':1,"desktop":2,'tablet':3})

# %%
# 총 9개의 결측치 존재 9개의 결측치는 삭제보다는 다른변수들을 이용하여 선형회귀예측값을 사용하는게 용이해 보임
from sklearn.linear_model import LinearRegression
Session_1 = Session[['SESS_SEQ','TOT_PAG_VIEW_CT','TOT_SESS_HR_V','DVC_CTG_NM']]

linreg = LinearRegression()

x_train = Session_1[Session_1['TOT_PAG_VIEW_CT'].notnull()].drop(columns='TOT_PAG_VIEW_CT')
y_train = Session_1[Session_1['TOT_PAG_VIEW_CT'].notnull()]['TOT_PAG_VIEW_CT']
x_test = Session_1[Session_1['TOT_PAG_VIEW_CT'].isnull()].drop(columns='TOT_PAG_VIEW_CT')
y_test = Session_1[Session_1['TOT_PAG_VIEW_CT'].isnull()]['TOT_PAG_VIEW_CT']

linreg.fit(x_train, y_train)

predicted = linreg.predict(x_test)

Session.TOT_PAG_VIEW_CT[Session.TOT_PAG_VIEW_CT.isnull()] = predicted

# %%
# 얘만 float형이면 헷갈리니까 그냥 int형으로 변환
Session['TOT_PAG_VIEW_CT'] = Session['TOT_PAG_VIEW_CT'].astype(int)

# %%
Session.isnull().sum()
# Out:
# CLNT_ID            0
# SESS_ID            0
# SESS_SEQ           0
# SESS_DT            0
# TOT_PAG_VIEW_CT    0
# TOT_SESS_HR_V      0
# DVC_CTG_NM         0
# ZON_NM             0
# CITY_NM            0
# SESS_MONTH         0
# SESS_DAY           0
# SESS_WEEK          0
# dtype: int64

# %%
# 예측변수에 사용하기위해 숫자로 매핑시킨걸 다시 문자로 매핑
# 다시 예측변수로 사용시 재매핑
Session['DVC_CTG_NM'] = Session['DVC_CTG_NM'].map({1:'mobile',2:"desktop",3:'tablet'})

# %%
Session.head()
# Out:
#    CLNT_ID   SESS_ID  SESS_SEQ    SESS_DT  TOT_PAG_VIEW_CT  TOT_SESS_HR_V  \
# 0  5873599   8641867         9 2018-05-09               82           1890
# 1  5873599   6616320        21 2018-06-11              105           1604
# 2  5873599   5886172        40 2018-06-24               41            632
# 3  5873884   1050889        15 2018-09-13              160           1035
# 4  5874461  10298270         5 2018-04-12               13            298
#
#   DVC_CTG_NM       ZON_NM  CITY_NM  SESS_MONTH  SESS_DAY  SESS_WEEK
# 0     mobile      Daejeon  Daejeon           5         9          2
# 1     mobile        Busan    Busan           6        11          0
# 2     mobile      Daejeon  Daejeon           6        24          6
# 3     mobile  Gyeonggi-do   Anyang           9        13          3
# 4     mobile        Seoul    Seoul           4        12          3

# %%
plt.figure(figsize=(15,8))
sns.countplot(Session['DVC_CTG_NM'])
plt.title("기기 유형 분포", fontsize=30)
plt.xlabel('DVC_CTG_NM', fontsize=18)
plt.ylabel('Count', fontsize=18)
plt.show()

# %%
# 대부분이 모바일로 접속
# 태블릿접속은 거의 드물다

# %%
figure = plt.figure(figsize=(15,8))
sns.barplot(data = Session , x= 'DVC_CTG_NM',y='TOT_SESS_HR_V')
plt.title("기기 유형 별 세션 시간", fontsize=30)
plt.xlabel('DVC_CTG_NM', fontsize=18)
plt.ylabel('Count', fontsize=18)
plt.show()

# %%
figure = plt.figure(figsize=(15,8))
sns.barplot(data = Session , x= 'DVC_CTG_NM',y='TOT_PAG_VIEW_CT')
plt.title("기기 유형 별 페이지 조회 수", fontsize=30)
plt.xlabel('DVC_CTG_NM', fontsize=18)
plt.ylabel('Count', fontsize=18)
plt.show()

# %%
# 모바일로 접속하는 경우가 월등히 많아 비교하기 어렵지만
# 그래도 알수있는 것은 Desktop으로 접속할경우 세션시간이 길고
# 모바일로 접속하면 페이지뷰가 많아짐
# 태블릿은 비교불가해보임(너무적음)

# %%
data = Session.groupby('DVC_CTG_NM')['TOT_SESS_HR_V'].mean()
data
# Out:
# DVC_CTG_NM
# desktop    1735.619719
# mobile     1399.340542
# tablet     1676.929155
# Name: TOT_SESS_HR_V, dtype: float64

# %%
# 지역별 구매 count
fig = plt.figure(figsize=(15,8))
print(Session['ZON_NM'].value_counts())
Session['ZON_NM'].value_counts().plot(kind='bar',fontsize=30)
# Out:
# Seoul                1013369
# Gyeonggi-do           467586
# Busan                 294509
# Gyeongsangnam-do      128177
# Daegu                 116189
# Incheon               100249
# Gyeongsangbuk-do       90806
# Jeollabuk-do           78160
# Chungcheongnam-do      77714
# Gwangju                70532
# Daejeon                60197
# Jeollanam-do           49078
# Ulsan                  46393
# Chungcheongbuk-do      44242
# Gangwon-do             42494
# Jeju-do                19010
# Name: ZON_NM, dtype: int64

# %%
data = Session['CITY_NM'].value_counts().nlargest(10)
data
# Out:
# Seoul        1013368
# Busan         294509
# Daegu         116189
# Incheon       100248
# Gwangju        70532
# Daejeon        60197
# Gimhae-si      48925
# Goyang-si      47424
# Suwon-si       46899
# Ulsan          46393
# Name: CITY_NM, dtype: int64

# %%
# 도시별 구매 count
fig = plt.figure(figsize=(15,8))
data = Session['CITY_NM'].value_counts().nlargest(10)
print(data)
data.plot(kind='bar',fontsize=30)
# Out:
# Seoul        1013368
# Busan         294509
# Daegu         116189
# Incheon       100248
# Gwangju        70532
# Daejeon        60197
# Gimhae-si      48925
# Goyang-si      47424
# Suwon-si       46899
# Ulsan          46393
# Name: CITY_NM, dtype: int64

# %%
fig,ax = plt.subplots(2,2,figsize=(15,8))
sns.distplot(Session['TOT_PAG_VIEW_CT'],ax=ax[0][0])
sns.distplot(Session['TOT_SESS_HR_V'],ax=ax[0][1])
sns.boxplot(Session['TOT_PAG_VIEW_CT'],ax=ax[1][0])
sns.boxplot(Session['TOT_SESS_HR_V'],ax=ax[1][1])
plt.show()

# %% [markdown]
# ## 1.3 Master

# %% [markdown]
# - 대분류 : 37개 / 중분류 : 128개 / 소분류 : 898 개

# %%
Master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 847652 entries, 0 to 847651
# Data columns (total 5 columns):
# PD_C        847652 non-null int64
# PD_NM       847652 non-null object
# CLAC1_NM    847652 non-null object
# CLAC2_NM    847652 non-null object
# CLAC3_NM    847652 non-null object
# dtypes: int64(1), object(4)
# memory usage: 32.3+ MB

# %%
Master.head()
# Out:
#     PD_C                                              PD_NM   CLAC1_NM  \
# 0  64382   언더아머 남성 UA HG 아머 모크 LS 1289559-001 - 블랙 / MD[95]      스포츠패션
# 1  62282                         여자 플라워덧신 2족선물세트 17403-2set  속옷/양말/홈웨어
# 2  61729                       88A2933253배트맨스웨트티 - 블랙 / 130      유아동의류
# 3  61537            닥터마틴 아드리안 블랙, 체리레드 - 02_체리레드 / 250mm(6)       패션잡화
# 4  58820  여성 그레이 스트라이프 퍼프 소매 블라우스 (128865YQ33) - 회색(앤틱실버...       남성의류
#
#     CLAC2_NM  CLAC3_NM
# 0  남성일반스포츠의류  남성스포츠티셔츠
# 1      여성양말류    여성일반양말
# 2     유아의류상의  영유아티셔츠/탑
# 3        남성화      남성부츠
# 4     남성의류상의    남성남방셔츠

# %%
Master['PD_NM'] = Master['PD_NM'].apply(cleanText)
Master['PD_NM'] = Master['PD_NM'].apply(cleanblank)

# %%
Master[['CLAC1_NM','CLAC2_NM','CLAC3_NM']].describe()
# Out:
#        CLAC1_NM CLAC2_NM CLAC3_NM
# count    847652   847652   847652
# unique       37      128      898
# top        여성의류   여성의류상의    남성티셔츠
# freq     181107    82731    41650

# %%
fig = plt.figure(figsize=(15,8))
data = Master['CLAC1_NM'].value_counts().nlargest(10)
data.plot(kind='bar',fontsize=30)

# %%
# 대분류 top 10
# 여성의류 - 패션잡화 - 스포츠패션 - 남성의류 - 유아동의류 - ....
# 여성의류가 압도적으로 높음

# %%
fig = plt.figure(figsize=(15,8))
data = Master['CLAC2_NM'].value_counts().nlargest(10)
data.plot(kind='bar',fontsize=30)

# %%
# 중분류 top 10
# 여성의류상의 - 남성의류상의 - 여성의류전신 - 여성의류하의 - 여성화

# %%
fig = plt.figure(figsize=(15,8))
data = Master['CLAC3_NM'].value_counts().nlargest(10)
data.plot(kind='bar',fontsize=30)

# %%
# 소분류 top 10 
# 남성티셔츠 - 여성원피스 - 여성남방셔츠 - 여성티셔츠/탑 - 여성바지

# %% [markdown]
# ## 1.4 Custom

# %%
Custom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671679 entries, 0 to 671678
# Data columns (total 3 columns):
# CLNT_ID        671679 non-null int64
# CLNT_GENDER    671679 non-null object
# CLNT_AGE       671679 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 15.4+ MB

# %%
Custom.head()
# Out:
#    CLNT_ID CLNT_GENDER  CLNT_AGE
# 0  4830726           F        30
# 1  4830874           F        40
# 2  4830975           F        30
# 3  4831275           F        30
# 4  4825325           F        30

# %%
Custom.nunique()
# Out:
# CLNT_ID        671679
# CLNT_GENDER         2
# CLNT_AGE            8
# dtype: int64

# %%
fig = plt.figure(figsize=(15,8))
print(Custom['CLNT_GENDER'].value_counts())
sns.countplot(Custom['CLNT_GENDER'])
# Out:
# F    570616
# M    101063
# Name: CLNT_GENDER, dtype: int64

# %%
# 여성회원수가 남성회원수보다 약 5.7배 많음

# %%
fig = plt.figure(figsize=(15,8))
data = Custom['CLNT_AGE'].value_counts()
print(data)
data.plot(kind='bar',fontsize=30)
# Out:
# 30    313600
# 40    216217
# 20     95297
# 50     36624
# 60      5256
# 10      3807
# 70       846
# 80        32
# Name: CLNT_AGE, dtype: int64

# %%
# 30 - 40 - 20 - 50 대 ....

# %% [markdown]
# ## 1.5 Search1

# %%
Search1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2884943 entries, 0 to 2884942
# Data columns (total 4 columns):
# CLNT_ID       int64
# SESS_ID       int64
# KWD_NM        object
# SEARCH_CNT    int64
# dtypes: int64(3), object(1)
# memory usage: 88.0+ MB

# %%
Search1.head()
# Out:
#    CLNT_ID  SESS_ID     KWD_NM  SEARCH_CNT
# 0  5607714  7112876   빌리프 아이크림           6
# 1  5607714  4090791  프리메라 마스크팩           3
# 2  5607714  4090791      여성청결제           1
# 3  5612428  1876482       명품가방           1
# 4  5612428   658123  콩순이 아이스크림           1

# %%
# 검색어에 특수문자 존재 할 수 있으므로 특수문자 모두 제거
Search1['KWD_NM'] = Search1['KWD_NM'].apply(cleanText)

# %%
fig = plt.figure(figsize=(15,8))
sns.distplot(Search1["SEARCH_CNT"])

# %%
# 가장 많이 검색된 횟수는 한 세션에서 98번까지 이루어짐
# 대부분의 값들은 10회미만으로 검색됨

# %% [markdown]
# ## 1.6 Search2

# %%
Search2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8051172 entries, 0 to 8051171
# Data columns (total 3 columns):
# SESS_DT       int64
# KWD_NM        object
# SEARCH_CNT    object
# dtypes: int64(1), object(2)
# memory usage: 184.3+ MB

# %%
Search2.head()
# Out:
#     SESS_DT     KWD_NM SEARCH_CNT
# 0  20180407      닥스원피스          8
# 1  20180407  닥터지 브라이트닝          1
# 2  20180407     달팡 인트랄          2
# 3  20180407        대상트          1
# 4  20180407       더블유닷          6

# %%
# 검색어에 특수문자 존재 할 수 있으므로 특수문자 모두 제거
Search2['KWD_NM'] = Search2['KWD_NM'].apply(cleanText)

# %% [markdown]
# # 2. 데이터 병합
# - Product + Session + Master + Custom - > df1
# - Product + + Master + Search1 -> df2

# %%
df_1 = pd.merge(Product,Master,on=["PD_C"],how='left')
df_1 = pd.merge(df_1,Custom,on=["CLNT_ID"],how='left')

# %%
# 약 100만개의 비회원 주문이 있음 전체데이터의 1/5

# %%
# 회원 / 비회원 변수 생성

df_1['MEMBER'] = df_1['CLNT_GENDER'].isnull()
df_1['MEMBER'] = df_1['MEMBER'].map({True:0,False:1})

# %%
# Custom에 없는 구매상품정보가있음 -> 비회원주문

# %%
df_1.head()
# Out:
#    CLNT_ID   SESS_ID  HITS_SEQ    PD_C                PD_ADD_NM PD_BRA_NM  \
# 0  4139680   7605037        12  642112                   색상워터멜론     바비브라운
# 1  4140076  10189797        13  570603  색상BLK0BLK0BLACK사이즈1202개       데상트
# 2  4142395   6158159        85  179538                   notset       아베다
# 3  4144914   7935714        12  554336      색상블랙사이즈160cm1213세1개   아디다스 키즈
# 4  4144917   6406509        78  190306                       5개      데코르테
#
#    PD_BUY_AM  PD_BUY_CT                           PD_NM  CLAC1_NM   CLAC2_NM  \
# 0      39000          1                       크러쉬드립칼라플럼  화장품/뷰티케어       메이크업
# 1      39000          2  데상트스포츠베이직빅로고티셔츠DMGRDMELANGE115     스포츠패션  남성일반스포츠의류
# 2      39000          1              단독6월라이트엘리먼츠헤어에센스세트     퍼스널케어       헤어케어
# 3      39000          1       YGGU34TGTABQ2873블랙110cm6세     유아동의류     여아의류하의
# 4      39000          5                단독허니듀세트5만원상당샘플증정  화장품/뷰티케어       스킨케어
#
#         CLAC3_NM CLNT_GENDER  CLNT_AGE  MEMBER
# 0  블러셔/쉐이딩/하이라이터         NaN       NaN       0
# 1       남성스포츠티셔츠           F      40.0       1
# 2       헤어케어선물세트         NaN       NaN       0
# 3          여아레깅스           M      40.0       1
# 4         스킨케어세트         NaN       NaN       0

# %%
# GENDER와 AGE는 비회원일 경우 Nan이기 때문에 소분류 를 통해 최빈값으로 대체
# 비회원이기 때문에 정보가 부족하기 때문에 완벽한 대체가 어려움
# 따라서 구매한 상품의 소분류의 각각의 최빈값으로 결측값을 채움

# 최빈값 추출 함수
def mode(x): return sp.stats.mode(x)[0][0]

# %%
####  GENDER
data = df_1[['CLAC3_NM','CLNT_GENDER']]

# 각각의 소분류 별로 최빈값을 추출
data_2 = df_1.groupby('CLAC3_NM')['CLNT_GENDER'].agg(mode)

# data와 data_2를 병합시켜 하나의 데이터프레임으로 만들어 줌
data_3 = pd.merge(data,data_2,on=['CLAC3_NM'],how='left')

# 원래값이 Nan이 아닌 애들은 그대로 그값을 사용, Nan값인 애들은 최빈값으로 대체 해줌
data_3['CLNT_GENDER'] = np.where(pd.notnull(data_3['CLNT_GENDER_x'])==True,data_3['CLNT_GENDER_x'],data_3['CLNT_GENDER_y'])

# Nan이 없는 새로운 값들로 열 대체
df_1['CLNT_GENDER'] = data_3['CLNT_GENDER']
df_1.head()
# Out:
#    CLNT_ID   SESS_ID  HITS_SEQ    PD_C                PD_ADD_NM PD_BRA_NM  \
# 0  4139680   7605037        12  642112                   색상워터멜론     바비브라운
# 1  4140076  10189797        13  570603  색상BLK0BLK0BLACK사이즈1202개       데상트
# 2  4142395   6158159        85  179538                   notset       아베다
# 3  4144914   7935714        12  554336      색상블랙사이즈160cm1213세1개   아디다스 키즈
# 4  4144917   6406509        78  190306                       5개      데코르테
#
#    PD_BUY_AM  PD_BUY_CT                           PD_NM  CLAC1_NM   CLAC2_NM  \
# 0      39000          1                       크러쉬드립칼라플럼  화장품/뷰티케어       메이크업
# 1      39000          2  데상트스포츠베이직빅로고티셔츠DMGRDMELANGE115     스포츠패션  남성일반스포츠의류
# 2      39000          1              단독6월라이트엘리먼츠헤어에센스세트     퍼스널케어       헤어케어
# 3      39000          1       YGGU34TGTABQ2873블랙110cm6세     유아동의류     여아의류하의
# 4      39000          5                단독허니듀세트5만원상당샘플증정  화장품/뷰티케어       스킨케어
#
#         CLAC3_NM CLNT_GENDER  CLNT_AGE  MEMBER
# 0  블러셔/쉐이딩/하이라이터           F       NaN       0
# 1       남성스포츠티셔츠           F      40.0       1
# 2       헤어케어선물세트           F       NaN       0
# 3          여아레깅스           M      40.0       1
# 4         스킨케어세트           F       NaN       0

# %%
####  AGE
data = df_1[['CLAC3_NM','CLNT_AGE']]

# 각각의 소분류 별로 최빈값을 추출
data_2 = df_1.groupby('CLAC3_NM')['CLNT_AGE'].agg(mode)

# data와 data_2를 병합시켜 하나의 데이터프레임으로 만들어 줌
data_3 = pd.merge(data,data_2,on=['CLAC3_NM'],how='left')

# 원래값이 Nan이 아닌 애들은 그대로 그값을 사용, Nan값인 애들은 최빈값으로 대체 해줌
data_3['CLNT_AGE'] = np.where(pd.notnull(data_3['CLNT_AGE_x'])==True,data_3['CLNT_AGE_x'],data_3['CLNT_AGE_y'])

# Nan이 없는 새로운 값들로 열 대체
df_1['CLNT_AGE'] = data_3['CLNT_AGE']
df_1.head()
# Out:
#    CLNT_ID   SESS_ID  HITS_SEQ    PD_C                PD_ADD_NM PD_BRA_NM  \
# 0  4139680   7605037        12  642112                   색상워터멜론     바비브라운
# 1  4140076  10189797        13  570603  색상BLK0BLK0BLACK사이즈1202개       데상트
# 2  4142395   6158159        85  179538                   notset       아베다
# 3  4144914   7935714        12  554336      색상블랙사이즈160cm1213세1개   아디다스 키즈
# 4  4144917   6406509        78  190306                       5개      데코르테
#
#    PD_BUY_AM  PD_BUY_CT                           PD_NM  CLAC1_NM   CLAC2_NM  \
# 0      39000          1                       크러쉬드립칼라플럼  화장품/뷰티케어       메이크업
# 1      39000          2  데상트스포츠베이직빅로고티셔츠DMGRDMELANGE115     스포츠패션  남성일반스포츠의류
# 2      39000          1              단독6월라이트엘리먼츠헤어에센스세트     퍼스널케어       헤어케어
# 3      39000          1       YGGU34TGTABQ2873블랙110cm6세     유아동의류     여아의류하의
# 4      39000          5                단독허니듀세트5만원상당샘플증정  화장품/뷰티케어       스킨케어
#
#         CLAC3_NM CLNT_GENDER  CLNT_AGE  MEMBER
# 0  블러셔/쉐이딩/하이라이터           F      30.0       0
# 1       남성스포츠티셔츠           F      40.0       1
# 2       헤어케어선물세트           F      30.0       0
# 3          여아레깅스           M      40.0       1
# 4         스킨케어세트           F      30.0       0

# %%
df_1.shape
# Out:
# (5019730, 15)

# %%
# 세션 정보가 없는 구매 데이터는 제외하고 진행(약 1.7만개)
# shape의 변화 : 5019730 -> 5002634 (inner조인 했기때문에 세션에 없는 정보들은 제외됨)
df_1 = pd.merge(df_1,Session,on=['CLNT_ID','SESS_ID'],how='inner')
df_1.head()
# Out:
#    CLNT_ID  SESS_ID  HITS_SEQ    PD_C PD_ADD_NM PD_BRA_NM  PD_BUY_AM  \
# 0  4139680  7605037        12  642112    색상워터멜론     바비브라운      39000
# 1  4139680  7605037        12  401577    색상몰리와우     바비브라운      39000
# 2  4139680  7605037        28  401577    색상몰리와우     바비브라운      39000
# 3  4139680  7605037        28  642112     색상카바나     바비브라운      39000
# 4  4139680  7605037        12  642112     색상카바나     바비브라운      39000
#
#    PD_BUY_CT             PD_NM  CLAC1_NM CLAC2_NM       CLAC3_NM CLNT_GENDER  \
# 0          1         크러쉬드립칼라플럼  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터           F
# 1          1  한정판크러쉬드립칼라20몰리와우  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터           F
# 2          1  한정판크러쉬드립칼라20몰리와우  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터           F
# 3          1         크러쉬드립칼라플럼  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터           F
# 4          1         크러쉬드립칼라플럼  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터           F
#
#    CLNT_AGE  MEMBER  SESS_SEQ    SESS_DT  TOT_PAG_VIEW_CT  TOT_SESS_HR_V  \
# 0      30.0       0         1 2018-05-26               21            902
# 1      30.0       0         1 2018-05-26               21            902
# 2      30.0       0         1 2018-05-26               21            902
# 3      30.0       0         1 2018-05-26               21            902
# 4      30.0       0         1 2018-05-26               21            902
#
#   DVC_CTG_NM ZON_NM CITY_NM  SESS_MONTH  SESS_DAY  SESS_WEEK
# 0    desktop  Seoul   Seoul           5        26          5
# 1    desktop  Seoul   Seoul           5        26          5
# 2    desktop  Seoul   Seoul           5        26          5
# 3    desktop  Seoul   Seoul           5        26          5
# 4    desktop  Seoul   Seoul           5        26          5

# %%
df_1.shape
# Out:
# (5002634, 25)

# %%
df_1.isnull().sum()
# Out:
# CLNT_ID            0
# SESS_ID            0
# HITS_SEQ           0
# PD_C               0
# PD_ADD_NM          0
# PD_BRA_NM          0
# PD_BUY_AM          0
# PD_BUY_CT          0
# PD_NM              0
# CLAC1_NM           0
# CLAC2_NM           0
# CLAC3_NM           0
# CLNT_GENDER        0
# CLNT_AGE           2
# MEMBER             0
# SESS_SEQ           0
# SESS_DT            0
# TOT_PAG_VIEW_CT    0
# TOT_SESS_HR_V      0
# DVC_CTG_NM         0
# ZON_NM             0
# CITY_NM            0
# SESS_MONTH         0
# SESS_DAY           0
# SESS_WEEK          0
# dtype: int64

# %%
df_1[df_1['CLNT_GENDER']==0]
# Out:
#          CLNT_ID  SESS_ID  HITS_SEQ    PD_C PD_ADD_NM PD_BRA_NM  PD_BUY_AM  \
# 1326017    60244  1038692        23  803426    notset      텐바이텐      10000
# 1326018    60244  1038692        23  803427     선택토리니      텐바이텐      23000
#
#          PD_BUY_CT           PD_NM CLAC1_NM CLAC2_NM CLAC3_NM CLNT_GENDER  \
# 1326017          1  DIY달콤쌉싸름초코양만들기       완구     여아완구    DIY완구           0
# 1326018          1  토리니곰이니만들기라지곰이니       완구     여아완구    DIY완구           0
#
#          CLNT_AGE  MEMBER  SESS_SEQ    SESS_DT  TOT_PAG_VIEW_CT  \
# 1326017       NaN       0         1 2018-09-13               22
# 1326018       NaN       0         1 2018-09-13               22
#
#          TOT_SESS_HR_V DVC_CTG_NM            ZON_NM    CITY_NM  SESS_MONTH  \
# 1326017            783    desktop  Gyeongsangbuk-do  Pohang-si           9
# 1326018            783    desktop  Gyeongsangbuk-do  Pohang-si           9
#
#          SESS_DAY  SESS_WEEK
# 1326017        13          3
# 1326018        13          3

# %%
# DIY완구의 경우 전체 데이터중 단 2개 존재 , 동일 고객 구매
# 해당고객의 다른 구매 물품을 찾아 존재하면 그 값으로 대체

# %%
df_1[df_1['CLAC3_NM']=="DIY완구"]
# Out:
#          CLNT_ID  SESS_ID  HITS_SEQ    PD_C PD_ADD_NM PD_BRA_NM  PD_BUY_AM  \
# 1326017    60244  1038692        23  803426    notset      텐바이텐      10000
# 1326018    60244  1038692        23  803427     선택토리니      텐바이텐      23000
#
#          PD_BUY_CT           PD_NM CLAC1_NM CLAC2_NM CLAC3_NM CLNT_GENDER  \
# 1326017          1  DIY달콤쌉싸름초코양만들기       완구     여아완구    DIY완구           0
# 1326018          1  토리니곰이니만들기라지곰이니       완구     여아완구    DIY완구           0
#
#          CLNT_AGE  MEMBER  SESS_SEQ    SESS_DT  TOT_PAG_VIEW_CT  \
# 1326017       NaN       0         1 2018-09-13               22
# 1326018       NaN       0         1 2018-09-13               22
#
#          TOT_SESS_HR_V DVC_CTG_NM            ZON_NM    CITY_NM  SESS_MONTH  \
# 1326017            783    desktop  Gyeongsangbuk-do  Pohang-si           9
# 1326018            783    desktop  Gyeongsangbuk-do  Pohang-si           9
#
#          SESS_DAY  SESS_WEEK
# 1326017        13          3
# 1326018        13          3

# %%
# 30대 / 여성 임을 확인
df_1[(df_1['CLNT_ID']==60244)&(df_1['SESS_ID']==1038692)]
# Out:
#          CLNT_ID  SESS_ID  HITS_SEQ    PD_C PD_ADD_NM PD_BRA_NM  PD_BUY_AM  \
# 1326013    60244  1038692        23  793045       선택양      바보사랑       5900
# 1326014    60244  1038692        23  793045      선택토끼      바보사랑       5900
# 1326015    60244  1038692        23  820301   선택3번고양이      바보사랑       8200
# 1326016    60244  1038692        23  820301   선택2번고양이      바보사랑       8200
# 1326017    60244  1038692        23  803426    notset      텐바이텐      10000
# 1326018    60244  1038692        23  803427     선택토리니      텐바이텐      23000
#
#          PD_BUY_CT                              PD_NM CLAC1_NM   CLAC2_NM  \
# 1326013          1  날아라미쎄스깡동물키링만들기패키지3종류9cm솜포함꿈꾸는두부토끼  문구/사무용품  일반문구/사무용품
# 1326014          1  날아라미쎄스깡동물키링만들기패키지3종류9cm솜포함꿈꾸는두부토끼  문구/사무용품  일반문구/사무용품
# 1326015          1              고양이미니인형DIY삼수니다락방3번고양이  문구/사무용품  일반문구/사무용품
# 1326016          1              고양이미니인형DIY삼수니다락방3번고양이  문구/사무용품  일반문구/사무용품
# 1326017          1                     DIY달콤쌉싸름초코양만들기       완구       여아완구
# 1326018          1                     토리니곰이니만들기라지곰이니       완구       여아완구
#
#             CLAC3_NM CLNT_GENDER  CLNT_AGE  MEMBER  SESS_SEQ    SESS_DT  \
# 1326013  기타일반문구/사무용품           F      30.0       0         1 2018-09-13
# 1326014  기타일반문구/사무용품           F      30.0       0         1 2018-09-13
# 1326015  기타일반문구/사무용품           F      30.0       0         1 2018-09-13
# 1326016  기타일반문구/사무용품           F      30.0       0         1 2018-09-13
# 1326017        DIY완구           0       NaN       0         1 2018-09-13
# 1326018        DIY완구           0       NaN       0         1 2018-09-13
#
#          TOT_PAG_VIEW_CT  TOT_SESS_HR_V DVC_CTG_NM            ZON_NM  \
# 1326013               22            783    desktop  Gyeongsangbuk-do
# 1326014               22            783    desktop  Gyeongsangbuk-do
# 1326015               22            783    desktop  Gyeongsangbuk-do
# 1326016               22            783    desktop  Gyeongsangbuk-do
# 1326017               22            783    desktop  Gyeongsangbuk-do
# 1326018               22            783    desktop  Gyeongsangbuk-do
#
#            CITY_NM  SESS_MONTH  SESS_DAY  SESS_WEEK
# 1326013  Pohang-si           9        13          3
# 1326014  Pohang-si           9        13          3
# 1326015  Pohang-si           9        13          3
# 1326016  Pohang-si           9        13          3
# 1326017  Pohang-si           9        13          3
# 1326018  Pohang-si           9        13          3

# %%
df_1['CLNT_GENDER'] = np.where(df_1['CLNT_GENDER']==0,"F",df_1['CLNT_GENDER'])
df_1['CLNT_AGE'] = np.where(pd.notnull(df_1['CLNT_AGE']),df_1['CLNT_AGE'],30.0)

# %%
# 잘 바뀌었음을 확인
df_1[(df_1['CLNT_ID']==60244)&(df_1['SESS_ID']==1038692)]
# Out:
#          CLNT_ID  SESS_ID  HITS_SEQ    PD_C PD_ADD_NM PD_BRA_NM  PD_BUY_AM  \
# 1326013    60244  1038692        23  793045       선택양      바보사랑       5900
# 1326014    60244  1038692        23  793045      선택토끼      바보사랑       5900
# 1326015    60244  1038692        23  820301   선택3번고양이      바보사랑       8200
# 1326016    60244  1038692        23  820301   선택2번고양이      바보사랑       8200
# 1326017    60244  1038692        23  803426    notset      텐바이텐      10000
# 1326018    60244  1038692        23  803427     선택토리니      텐바이텐      23000
#
#          PD_BUY_CT                              PD_NM CLAC1_NM   CLAC2_NM  \
# 1326013          1  날아라미쎄스깡동물키링만들기패키지3종류9cm솜포함꿈꾸는두부토끼  문구/사무용품  일반문구/사무용품
# 1326014          1  날아라미쎄스깡동물키링만들기패키지3종류9cm솜포함꿈꾸는두부토끼  문구/사무용품  일반문구/사무용품
# 1326015          1              고양이미니인형DIY삼수니다락방3번고양이  문구/사무용품  일반문구/사무용품
# 1326016          1              고양이미니인형DIY삼수니다락방3번고양이  문구/사무용품  일반문구/사무용품
# 1326017          1                     DIY달콤쌉싸름초코양만들기       완구       여아완구
# 1326018          1                     토리니곰이니만들기라지곰이니       완구       여아완구
#
#             CLAC3_NM CLNT_GENDER  CLNT_AGE  MEMBER  SESS_SEQ    SESS_DT  \
# 1326013  기타일반문구/사무용품           F      30.0       0         1 2018-09-13
# 1326014  기타일반문구/사무용품           F      30.0       0         1 2018-09-13
# 1326015  기타일반문구/사무용품           F      30.0       0         1 2018-09-13
# 1326016  기타일반문구/사무용품           F      30.0       0         1 2018-09-13
# 1326017        DIY완구           F      30.0       0         1 2018-09-13
# 1326018        DIY완구           F      30.0       0         1 2018-09-13
#
#          TOT_PAG_VIEW_CT  TOT_SESS_HR_V DVC_CTG_NM            ZON_NM  \
# 1326013               22            783    desktop  Gyeongsangbuk-do
# 1326014               22            783    desktop  Gyeongsangbuk-do
# 1326015               22            783    desktop  Gyeongsangbuk-do
# 1326016               22            783    desktop  Gyeongsangbuk-do
# 1326017               22            783    desktop  Gyeongsangbuk-do
# 1326018               22            783    desktop  Gyeongsangbuk-do
#
#            CITY_NM  SESS_MONTH  SESS_DAY  SESS_WEEK
# 1326013  Pohang-si           9        13          3
# 1326014  Pohang-si           9        13          3
# 1326015  Pohang-si           9        13          3
# 1326016  Pohang-si           9        13          3
# 1326017  Pohang-si           9        13          3
# 1326018  Pohang-si           9        13          3

# %%
# Search1, Search2 제외한 테이블생성
# Product + Master + Custom + Session
df_1.to_csv("PMCS.csv",index=False)

# %%
Search1.head()
# Out:
#    CLNT_ID  SESS_ID     KWD_NM  SEARCH_CNT
# 0  5607714  7112876   빌리프 아이크림           6
# 1  5607714  4090791  프리메라 마스크팩           3
# 2  5607714  4090791      여성청결제           1
# 3  5612428  1876482       명품가방           1
# 4  5612428   658123  콩순이 아이스크림           1

# %%
df_2 = pd.merge(df_1,Search1,on=["CLNT_ID","SESS_ID"],how='left')
df_2.head()
# Out:
#    CLNT_ID  SESS_ID  HITS_SEQ    PD_C PD_ADD_NM PD_BRA_NM  PD_BUY_AM  \
# 0  4139680  7605037        12  642112    색상워터멜론     바비브라운      39000
# 1  4139680  7605037        12  401577    색상몰리와우     바비브라운      39000
# 2  4139680  7605037        28  401577    색상몰리와우     바비브라운      39000
# 3  4139680  7605037        28  642112     색상카바나     바비브라운      39000
# 4  4139680  7605037        12  642112     색상카바나     바비브라운      39000
#
#    PD_BUY_CT             PD_NM  CLAC1_NM CLAC2_NM       CLAC3_NM CLNT_GENDER  \
# 0          1         크러쉬드립칼라플럼  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터           F
# 1          1  한정판크러쉬드립칼라20몰리와우  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터           F
# 2          1  한정판크러쉬드립칼라20몰리와우  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터           F
# 3          1         크러쉬드립칼라플럼  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터           F
# 4          1         크러쉬드립칼라플럼  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터           F
#
#    CLNT_AGE  MEMBER  SESS_SEQ    SESS_DT  TOT_PAG_VIEW_CT  TOT_SESS_HR_V  \
# 0      30.0       0         1 2018-05-26               21            902
# 1      30.0       0         1 2018-05-26               21            902
# 2      30.0       0         1 2018-05-26               21            902
# 3      30.0       0         1 2018-05-26               21            902
# 4      30.0       0         1 2018-05-26               21            902
#
#   DVC_CTG_NM ZON_NM CITY_NM  SESS_MONTH  SESS_DAY  SESS_WEEK KWD_NM  \
# 0    desktop  Seoul   Seoul           5        26          5    NaN
# 1    desktop  Seoul   Seoul           5        26          5    NaN
# 2    desktop  Seoul   Seoul           5        26          5    NaN
# 3    desktop  Seoul   Seoul           5        26          5    NaN
# 4    desktop  Seoul   Seoul           5        26          5    NaN
#
#    SEARCH_CNT
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df_2.shape
# Out:
# (9002383, 27)

# %%
df_2.isnull().sum()
# Out:
# CLNT_ID                  0
# SESS_ID                  0
# HITS_SEQ                 0
# PD_C                     0
# PD_ADD_NM                0
# PD_BRA_NM                0
# PD_BUY_AM                0
# PD_BUY_CT                0
# PD_NM                    0
# CLAC1_NM                 0
# CLAC2_NM                 0
# CLAC3_NM                 0
# CLNT_GENDER              0
# CLNT_AGE                 0
# MEMBER                   0
# SESS_SEQ                 0
# SESS_DT                  0
# TOT_PAG_VIEW_CT          0
# TOT_SESS_HR_V            0
# DVC_CTG_NM               0
# ZON_NM                   0
# CITY_NM                  0
# SESS_MONTH               0
# SESS_DAY                 0
# SESS_WEEK                0
# KWD_NM             2564097
# SEARCH_CNT         2564097
# dtype: int64

# %%
# Search2 제외한 테이블생성
# Product + Master + Custom + Session + Search1
df_2.to_csv("PMCSS.csv",index=False)

# %%
################################ 병합 끝 ####################################

# %%
# PD_ADD_NM, PD_BRA_NM, PD_NM, CLAC1_NM, CLAC2_NM, CLAC3_NM
# vs KWD_NM
# 모두 동일하게 진행하여 검색지수를 생성
# 검색지수 : 고객이 얼마나 목적성을 갖고 검색을 하는가에 대한 지표

#################### 검색과정 ####################

# 대/중/소 분류로 검색을 하는 고객, 특정 브랜드로 검색을 하는 고객, 상품명, (사이즈, 색상)
# 등으로 다양하게 검색이 이루어질것으로 예상
# 6개의 변수와 Search1의 검색어변수의 유사도를 구하여 실제로 구매로 이루어지는 정도(가중치)를
# 파악하여 가중합으로 검색지표를 생성

# 고려해야할 것
# PD_NM과 PD_ADD_NM 의 경우 옵션, 영문 처리를 어떻게 할지?
# 특수문자 제거 후 어떻게 나눠야 할까

# 문제점 
# 반팔 <> 티셔츠 => 같은 의미의 단어지만 검색을 어떻게 했느냐에따라 검색지수가 다르게 나옴
# 문장유사도 분석으로는 이런차이를 모두 확인하기 어려움
# 불완전하지만 다른 지표들을 더 생성해서 보완해야 할듯

# 하지만 문장유사도를 보려면 이방법 밖에 없는듯....
# 연관검색어 등으로 접근하려면 word2vec 사용 고려

# %%
# 검색어없이 구매된 데이터가 있음 
# 클릭만 해서 구매했거나 혹은 오류값이거나
# 특수문자 제거 과정에서 검색어가 공백이 된것들이 존재
# 원래 특수문자 밖에 없었으므로 제거해도 무방

df = df_2[df_2['KWD_NM'].notnull()]
df = df[df['KWD_NM']!='']

# %%
data = df[['CLNT_ID','SESS_ID','PD_C','PD_ADD_NM','PD_BRA_NM','PD_NM','CLAC1_NM','CLAC2_NM','CLAC3_NM','KWD_NM']]

# %%
data.head()
# Out:
#     CLNT_ID  SESS_ID    PD_C        PD_ADD_NM PD_BRA_NM  \
# 8   4142395  6158159  179538           notset       아베다
# 9   4142395  6158159  179538           notset       아베다
# 10  4142395  6158159  179538           notset       아베다
# 11  4142395  6158159  179538           notset       아베다
# 12  4142395  6158159  558739  상품명이솝제라늄리프바디클렌저        이솝
#
#                             PD_NM CLAC1_NM CLAC2_NM  CLAC3_NM   KWD_NM
# 8              단독6월라이트엘리먼츠헤어에센스세트    퍼스널케어     헤어케어  헤어케어선물세트     입생로랑
# 9              단독6월라이트엘리먼츠헤어에센스세트    퍼스널케어     헤어케어  헤어케어선물세트       이솝
# 10             단독6월라이트엘리먼츠헤어에센스세트    퍼스널케어     헤어케어  헤어케어선물세트  아베다 스무드
# 11             단독6월라이트엘리먼츠헤어에센스세트    퍼스널케어     헤어케어  헤어케어선물세트      아베다
# 12  이솝제라늄리프바디클렌저500ml이솝제라늄리프바디클렌저    퍼스널케어     바디케어      바디워시     입생로랑

# %%
# 문장의 유사도 분석
# (KWD_NM과 PD_BRA_NM의 공통 단어) / (KWD_NM의 단어)
# 단어를 2음절씩 나눈이유 : 2음절씩 나누면 문장의 단어를 최대한 세분화해서볼수있음
# 1개는 단어의 의미를 잃기 때문에 안됨

## n_gram
def ngram(s,num):
    res = []
    slen = len(s)#-num+1
    for i in range(slen):
        ss = s[i:i+num]
        res.append(ss)
    return res

def diff_ngram(sa,sb,num):
    a = ngram(sa,num)
    b = ngram(sb,num)
    r = []
    cnt = 0
    for i in a:
        for j in b:
            if i==j:
                cnt +=1
                r.append(i)
    return cnt / len(b)#, r
# 겹치는 단어가 어떤건지 필요하면 r 도 함께 return

def search_index(df,a):
    r = []
    for i in range(len(df)):
        rr = diff_ngram(df[a].iloc[i],df["KWD_NM"].iloc[i],2)
        r.append(rr)
    return r

# %%
# 예시
print(ngram(data['KWD_NM'].iloc[16],2))
print(ngram(data['PD_BRA_NM'].iloc[16],2))
print(data['PD_BRA_NM'].iloc[16],data['KWD_NM'].iloc[16])
r2= diff_ngram(data['PD_BRA_NM'].iloc[16],data['KWD_NM'].iloc[16],2)
print(r2)
# Out:
# ['입생', '생로', '로랑', '랑']
# ['아베', '베다', '다']
# 아베다 입생로랑
# 0.0

# %%
# 추가정보에서 숫자만 있는 행도 존재하므로 str형식으로 바꿔 ngram analysis 진행
data["PD_ADD_NM"] = data["PD_ADD_NM"].astype(str)

# %%
# 컬럼별 문장 유사도 생성 
data['brand_search_index'] = search_index(data,"PD_BRA_NM")
data['PD_NM_search_index'] = search_index(data,"PD_NM")
data['PD_ADD_NM_search_index'] = search_index(data,"PD_ADD_NM")
data['CLAC1_NM_search_index'] = search_index(data,"CLAC1_NM")
data['CLAC2_NM_search_index'] = search_index(data,"CLAC2_NM")
data['CLAC3_NM_search_index'] = search_index(data,"CLAC3_NM")

# %%
# PD_NM과 KWD_NM과의 ngram 분석시 1이넘는 값들이 존재
# 같은 단어가 반복해서 나오면 분모보다 분자가 큰 경우가 발생
# P(A|B) -> 조건부 확률 : B가 일어났을때 A가 일어날 확률 
# = P(AΠB) / P(B) : 검색(B)이 이루어졌을때 해당 상품정보로 구매(A)할 확률
# 이 값들은 어짜피 0보다 크면 어떠한 목적성이 있다고 판단하여 값을 1로 할 것이기 때문에 문제X

# %%
# 최종 변수 생성
data['index'] = data['brand_search_index']+data['PD_NM_search_index']+data['PD_ADD_NM_search_index']+data['CLAC1_NM_search_index']+data['CLAC2_NM_search_index']+data['CLAC3_NM_search_index']

# %%
data.head()
# Out:
#     CLNT_ID  SESS_ID    PD_C        PD_ADD_NM PD_BRA_NM  \
# 8   4142395  6158159  179538           notset       아베다
# 9   4142395  6158159  179538           notset       아베다
# 10  4142395  6158159  179538           notset       아베다
# 11  4142395  6158159  179538           notset       아베다
# 12  4142395  6158159  558739  상품명이솝제라늄리프바디클렌저        이솝
#
#                             PD_NM CLAC1_NM CLAC2_NM  CLAC3_NM   KWD_NM  \
# 8              단독6월라이트엘리먼츠헤어에센스세트    퍼스널케어     헤어케어  헤어케어선물세트     입생로랑
# 9              단독6월라이트엘리먼츠헤어에센스세트    퍼스널케어     헤어케어  헤어케어선물세트       이솝
# 10             단독6월라이트엘리먼츠헤어에센스세트    퍼스널케어     헤어케어  헤어케어선물세트  아베다 스무드
# 11             단독6월라이트엘리먼츠헤어에센스세트    퍼스널케어     헤어케어  헤어케어선물세트      아베다
# 12  이솝제라늄리프바디클렌저500ml이솝제라늄리프바디클렌저    퍼스널케어     바디케어      바디워시     입생로랑
#
#     brand_search_index  PD_NM_search_index  PD_ADD_NM_search_index  \
# 8             0.000000                 0.0                     0.0
# 9             0.000000                 0.0                     0.0
# 10            0.285714                 0.0                     0.0
# 11            1.000000                 0.0                     0.0
# 12            0.000000                 0.0                     0.0
#
#     CLAC1_NM_search_index  CLAC2_NM_search_index  CLAC3_NM_search_index  \
# 8                     0.0                    0.0                    0.0
# 9                     0.0                    0.0                    0.0
# 10                    0.0                    0.0                    0.0
# 11                    0.0                    0.0                    0.0
# 12                    0.0                    0.0                    0.0
#
#        index
# 8   0.000000
# 9   0.000000
# 10  0.285714
# 11  1.000000
# 12  0.000000

# %%
# 검색 목적 지수를 binary 형태로 변환 하여 이진분류로 만들어 줌
data["search_purpose"] = np.where(data["index"] == 0, 0, 1)

# %%
fig = plt.figure(figsize = (15,8))
sns.countplot(data['search_purpose'])

# %% [markdown]
# # -> target값이 매우 균형적

# %%
# Product , Master , Custom, Session, Search1 이 합쳐진 테이블에 타겟변수 생성
df['search_purpose'] = data['search_purpose']
df['search_purpose_index'] = data['index']

# %%
df.head()
# Out:
#     CLNT_ID  SESS_ID  HITS_SEQ    PD_C        PD_ADD_NM PD_BRA_NM  PD_BUY_AM  \
# 8   4142395  6158159        85  179538           notset       아베다      39000
# 9   4142395  6158159        85  179538           notset       아베다      39000
# 10  4142395  6158159        85  179538           notset       아베다      39000
# 11  4142395  6158159        85  179538           notset       아베다      39000
# 12  4142395  6158159        23  558739  상품명이솝제라늄리프바디클렌저        이솝      56000
#
#     PD_BUY_CT                          PD_NM CLAC1_NM CLAC2_NM  CLAC3_NM  \
# 8           1             단독6월라이트엘리먼츠헤어에센스세트    퍼스널케어     헤어케어  헤어케어선물세트
# 9           1             단독6월라이트엘리먼츠헤어에센스세트    퍼스널케어     헤어케어  헤어케어선물세트
# 10          1             단독6월라이트엘리먼츠헤어에센스세트    퍼스널케어     헤어케어  헤어케어선물세트
# 11          1             단독6월라이트엘리먼츠헤어에센스세트    퍼스널케어     헤어케어  헤어케어선물세트
# 12          1  이솝제라늄리프바디클렌저500ml이솝제라늄리프바디클렌저    퍼스널케어     바디케어      바디워시
#
#    CLNT_GENDER  CLNT_AGE  MEMBER  SESS_SEQ    SESS_DT  TOT_PAG_VIEW_CT  \
# 8            F      30.0       0         1 2018-06-19              107
# 9            F      30.0       0         1 2018-06-19              107
# 10           F      30.0       0         1 2018-06-19              107
# 11           F      30.0       0         1 2018-06-19              107
# 12           F      30.0       0         1 2018-06-19              107
#
#     TOT_SESS_HR_V DVC_CTG_NM ZON_NM CITY_NM  SESS_MONTH  SESS_DAY  SESS_WEEK  \
# 8            6524    desktop  Seoul   Seoul           6        19          1
# 9            6524    desktop  Seoul   Seoul           6        19          1
# 10           6524    desktop  Seoul   Seoul           6        19          1
# 11           6524    desktop  Seoul   Seoul           6        19          1
# 12           6524    desktop  Seoul   Seoul           6        19          1
#
#      KWD_NM  SEARCH_CNT  search_purpose
# 8      입생로랑         3.0               0
# 9        이솝         3.0               0
# 10  아베다 스무드         1.0               1
# 11      아베다        23.0               1
# 12     입생로랑         3.0               0

# %%
df.to_csv("final_data.csv",index=False)

# %%
########### 고려필요 ###########
# 검색이 몇번이루어졌는지
# 세션의 시간과 페이지뷰 수
# 몇개를 구매했는지, 얼마짜리를 샀는지
# 세션이 얼마나 많이 생성되었는지(HITS_SEQ)
